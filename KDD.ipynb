# %% [markdown]
# <a href="https://colab.research.google.com/github/SoungbinC/CMPE_255/blob/assignment3/KDD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# KDD Steps
#
# 1. Pre KDD
# 2. Selection
# 3. Pre processing
# 4. Tranformation
# 5. Data mining
# 6. Interpretation/Evaluation
# 7. Post KDD

# %% [markdown]
# ##Pre Kdd

# %%
import pandas as pd
import numpy as np


x = pd.read_csv('Credit_card.csv')
y = pd.read_csv('Credit_card_label.csv')


dataset = pd.concat([X, y], axis=1)
df.head()
# Out:
#   GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0      M         Y             Y         0       180000.0
# 1      F         Y             N         0       315000.0
# 2      F         Y             N         0       315000.0
# 3      F         Y             N         0            NaN
# 4    NaN         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4             Pensioner  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Family_Members  label
# 0        -18772.0         365243               2      1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1386 entries, 0 to 1385
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GENDER          1379 non-null   object
#  1   Car_Owner       1386 non-null   object
#  2   Propert_Owner   1386 non-null   object
#  3   CHILDREN        1386 non-null   int64
#  4   Annual_income   1363 non-null   float64
#  5   Type_Income     1386 non-null   object
#  6   EDUCATION       1386 non-null   object
#  7   Marital_status  1386 non-null   object
#  8   Housing_type    1386 non-null   object
#  9   Birthday_count  1364 non-null   float64
#  10  Employed_days   1386 non-null   int64
#  11  Family_Members  1386 non-null   int64
#  12  label           1386 non-null   int64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 140.9+ KB

# %% [markdown]
# ##Selection and Pre processing

# %%
df.isnull().sum()
# Out:
# GENDER             7
# Car_Owner          0
# Propert_Owner      0
# CHILDREN           0
# Annual_income     23
# Type_Income        0
# EDUCATION          0
# Marital_status     0
# Housing_type       0
# Birthday_count    22
# Employed_days      0
# Family_Members     0
# label              0
# dtype: int64

# %%
dataset.drop(["Ind_ID"], axis=1, inplace=True)

# %%
df = df.drop_duplicates().reset_index().drop('index',axis=1)

# %%
df.isnull().sum()
# Out:
# GENDER               7
# Car_Owner            0
# Propert_Owner        0
# CHILDREN             0
# Annual_income       23
# Type_Income          0
# EDUCATION            0
# Marital_status       0
# Housing_type         0
# Birthday_count      22
# Employed_days        0
# Type_Occupation    438
# Family_Members       0
# label                0
# dtype: int64

# %%
dataset["CHILDREN"].value_counts()
# Out:
# 0     1091
# 1      305
# 2      134
# 3       16
# 4        1
# 14       1
# Name: CHILDREN, dtype: int64

# %%
dataset.drop(dataset[dataset["CHILDREN"] == 14].index, axis=0, inplace=True)

# %%
dataset["EDUCATION"].unique()
# Out:
# array(['Higher education', 'Secondary', 'Lower secondary',
#        'Incomplete higher', 'Academic degree'], dtype=object)

# %%
dataset["EDUCATION"].replace("Secondary / secondary special", "Secondary", inplace=True)

# %%
dataset["Marital_status"].unique()
# Out:
# array(['Married', 'Single / not married', 'Civil marriage', 'Separated',
#        'Widow'], dtype=object)

# %%
dataset["Marital_status"].replace("Single / not married", "Single", inplace=True)

# %%
dataset["Housing_type"].unique()
# Out:
# array(['House / apartment', 'With parents', 'Rented apartment',
#        'Municipal apartment', 'Co-op apartment', 'Office apartment'],
#       dtype=object)

# %%
dataset["Housing_type"].replace("House / apartment", "House", inplace=True)

# %%
dataset["Family_Members"].unique()
# Out:
# array([2, 3, 1, 4, 6, 5])

# %%
dataset["GENDER"].value_counts()
# Out:
# F    973
# M    567
# Name: GENDER, dtype: int64

# %%
dataset["GENDER"].fillna("F", inplace=True)

# %%
meansval = dataset["Annual_income"].mean()
dataset["Annual_income"].fillna(meansval, inplace = True)

# %%
meansval = dataset["Birthday_count"].mean()
dataset["Birthday_count"].fillna(meansval, inplace = True)

# %%
dataset.drop(["Type_Occupation"], axis=1, inplace=True)

# %%
dataset.head()
# Out:
#   GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0      M         Y             Y         0  180000.000000
# 1      F         Y             N         0  315000.000000
# 2      F         Y             N         0  315000.000000
# 3      F         Y             N         0  191377.278543
# 4      F         Y             N         0  315000.000000
#
#             Type_Income         EDUCATION Marital_status Housing_type  \
# 0             Pensioner  Higher education        Married        House
# 1  Commercial associate  Higher education        Married        House
# 2  Commercial associate  Higher education        Married        House
# 3  Commercial associate  Higher education        Married        House
# 4  Commercial associate  Higher education        Married        House
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# 0   -18772.000000         365243             1           0      0         0
# ...

# %%
dataset.isnull().sum()
# Out:
# GENDER            0
# Car_Owner         0
# Propert_Owner     0
# CHILDREN          0
# Annual_income     0
# Type_Income       0
# EDUCATION         0
# Marital_status    0
# Housing_type      0
# Birthday_count    0
# Employed_days     0
# Mobile_phone      0
# Work_Phone        0
# Phone             0
# EMAIL_ID          0
# Family_Members    0
# label             0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1547 entries, 0 to 1547
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GENDER          1547 non-null   object
#  1   Car_Owner       1547 non-null   object
#  2   Propert_Owner   1547 non-null   object
#  3   CHILDREN        1547 non-null   int64
#  4   Annual_income   1547 non-null   float64
#  5   Type_Income     1547 non-null   object
#  6   EDUCATION       1547 non-null   object
#  7   Marital_status  1547 non-null   object
#  8   Housing_type    1547 non-null   object
#  9   Birthday_count  1547 non-null   float64
#  10  Employed_days   1547 non-null   int64
#  11  Mobile_phone    1547 non-null   int64
#  12  Work_Phone      1547 non-null   int64
#  13  Phone           1547 non-null   int64
#  14  EMAIL_ID        1547 non-null   int64
#  15  Family_Members  1547 non-null   int64
#  16  label           1547 non-null   int64
# ...

# %%
dataset = pd.get_dummies(data = dataset, drop_first = True)

# %%
dataset.head()
# Out:
#    CHILDREN  Annual_income  Birthday_count  Employed_days  Mobile_phone  \
# 0         0  180000.000000   -18772.000000         365243             1
# 1         0  315000.000000   -13557.000000           -586             1
# 2         0  315000.000000   -16039.218361           -586             1
# 3         0  191377.278543   -13557.000000           -586             1
# 4         0  315000.000000   -13557.000000           -586             1
#
#    Work_Phone  Phone  EMAIL_ID  Family_Members  label  ...  \
# 0           0      0         0               2      1  ...
# 1           1      1         0               2      1  ...
# 2           1      1         0               2      1  ...
# 3           1      1         0               2      1  ...
# 4           1      1         0               2      1  ...
#
#    EDUCATION_Secondary  Marital_status_Married  Marital_status_Separated  \
# 0                    0                       1                         0
# ...

# %%
X = dataset.iloc[:, :-1]
y = dataset.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
X_train
# Out:
#       CHILDREN  Annual_income  Birthday_count  Employed_days  Mobile_phone  \
# 246          1       292500.0        -16632.0          -1679             1
# 81           0       135000.0        -13581.0          -2576             1
# 120          0       126000.0        -14522.0           -863             1
# 768          0       135000.0        -15371.0          -3332             1
# 274          1       450000.0        -17726.0           -708             1
# ...        ...            ...             ...            ...           ...
# 1123         0       135000.0        -15438.0          -3377             1
# 1347         0       180000.0        -23365.0         365243             1
# 1407         0       405000.0        -18517.0          -3944             1
# 1390         0       165600.0        -21383.0         365243             1
# 1535         0       144000.0        -19984.0          -4662             1
#
#       Work_Phone  Phone  EMAIL_ID  Family_Members  label  ...  \
# ...

# %%
y_train
# Out:
# 246     0
# 81      0
# 120     0
# 768     0
# 274     0
#        ..
# 1123    0
# 1347    0
# 1407    0
# 1390    0
# 1535    0
# Name: Housing_type_With parents, Length: 1082, dtype: uint8

# %% [markdown]
# ### Transformation and Data mining

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 35.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 20.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 23.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 65.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 67.4 MB/s eta 0:00:00
# ...

# %%
from pycaret.classification import *
s = setup(data=dataset, target = 'default', session_id = 123)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-5765a2f4130b> in <cell line: 2>()
#       1 from pycaret.classification import *
# ----> 2 s = setup(data=dataset, target = 'default', session_id = 123)
#
# ...
