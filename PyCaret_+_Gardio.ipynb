# %% [markdown]
# <a href="https://colab.research.google.com/github/SoungbinC/CMPE_255/blob/assignment2/PyCaret_%2B_Gardio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install Pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 33.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 26.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 38.9 MB/s eta 0:00:00
# ...

# %%
pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 38.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 5.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 22.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 21.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 8.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# #PyCaret + Gradio

# %%
from pycaret.datasets import get_data
data = get_data('diamond')
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171

# %%
from pycaret.regression import *
s = setup(data,target="Price",session_id=123)
# Out:
# <style type="text/css">
# #T_d63b3_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d63b3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d63b3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d63b3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d63b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d63b3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d63b3_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d63b3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d63b3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d63b3_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_d63b3_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_d1779_row10_col0, #T_d1779_row10_col1, #T_d1779_row10_col2, #T_d1779_row10_col3, #T_d1779_row10_col4, #T_d1779_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d1779" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1779_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d1779_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d1779_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d1779_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d1779_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d1779_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
create_app(dt)
# Out:
# /usr/local/lib/python3.10/dist-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:5442: GradioDeprecationWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   all_inputs.append(gr.inputs.Textbox(label=i))
# /usr/local/lib/python3.10/dist-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:5442: GradioDeprecationWarning: `optional` parameter is deprecated, and it has no effect
#   all_inputs.append(gr.inputs.Textbox(label=i))
# /usr/local/lib/python3.10/dist-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:5442: GradioDeprecationWarning: `numeric` parameter is deprecated, and it has no effect
#   all_inputs.append(gr.inputs.Textbox(label=i))
# ...

# %% [markdown]
# # Clustering_function example
# *italicized text*

# %%
from pycaret.datasets import get_data
data= get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
from pycaret.classification import *
s = setup(data,target='species', session_id=123)
# Out:
# <style type="text/css">
# #T_ca4b8_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ca4b8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca4b8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ca4b8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca4b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ca4b8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ca4b8_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ca4b8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ca4b8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ca4b8_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_ca4b8_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_426b4_row10_col0, #T_426b4_row10_col1, #T_426b4_row10_col2, #T_426b4_row10_col3, #T_426b4_row10_col4, #T_426b4_row10_col5, #T_426b4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_426b4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_426b4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_426b4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_426b4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_426b4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_426b4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_426b4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_426b4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
create_app(dt)
# Out:
# /usr/local/lib/python3.10/dist-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:5442: GradioDeprecationWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   all_inputs.append(gr.inputs.Textbox(label=i))
# /usr/local/lib/python3.10/dist-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:5442: GradioDeprecationWarning: `optional` parameter is deprecated, and it has no effect
#   all_inputs.append(gr.inputs.Textbox(label=i))
# /usr/local/lib/python3.10/dist-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:5442: GradioDeprecationWarning: `numeric` parameter is deprecated, and it has no effect
#   all_inputs.append(gr.inputs.Textbox(label=i))
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# ...
