# %% [markdown]
# <a href="https://colab.research.google.com/github/SoungbinC/CMPE_255/blob/assignment3/Wine_KDD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# KDD Steps
#
# 1. Pre KDD
# 2. Selection
# 3. Pre processing
# 4. Tranformation
# 5. Data mining
# 6. Interpretation/Evaluation
# 7. Post KDD

# %% [markdown]
# ##Pre Kdd

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import Image


df = pd.read_csv("wine.csv")
df
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
df.describe()
# Out:
#           Alcohol  Malic_Acid         Ash  Ash_Alcanity   Magnesium  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#        Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %% [markdown]
# ##Selection and Pre processing

# %%
df.isnull().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = df[(df['Color_Intensity']<10.5)]
df = df[(df['Magnesium']<130.5)]
df.reset_index(drop=True,inplace=True)
df
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 162    13.71        5.65  2.45          20.5         95           1.68
# 163    13.40        3.91  2.48          23.0        102           1.80
# 164    13.27        4.28  2.26          20.0        120           1.59
# 165    13.17        2.59  2.37          20.0        120           1.65
# 166    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
import scipy.stats
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
scaler = StandardScaler()
scaler.fit(df)
df = pd.DataFrame(scaler.transform(df),columns= df.columns)

# %% [markdown]
# ### Tranformation,Data mining, and evaluation

# %%
pca = PCA(n_components=3)
pca.fit(df)
df = pd.DataFrame(pca.transform(df), columns=(["col1","col2", "col3"]))
df.describe().T
# Out:
#       count          mean       std       min       25%       50%       75%  \
# col1  178.0 -1.596725e-16  2.175417 -4.280639 -2.172762  0.060511  2.001293
# col2  178.0 -9.979533e-17  1.584639 -3.515090 -1.233675 -0.262030  1.398300
# col3  178.0  9.979533e-18  1.205920 -4.585064 -0.831188 -0.141612  0.760061
#
#            max
# col1  4.312784
# col2  3.871784
# col3  5.345388

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection="3d")
ax.scatter(df["col1"],df["col2"],df["col3"], c="red", marker="o")
ax.set_title("Projection Of Data in 3D")
plt.show()

# %%
AC = AgglomerativeClustering(n_clusters=3)
yhat_AC = AC.fit_predict(df)

df["Clusters"] = yhat_AC

# %%
fig = plt.figure(figsize=(10,8))
ax = plt.subplot(111, projection='3d', label="bla")
ax.scatter(df["col1"],df["col2"],df["col3"], s=40, c=df["Clusters"], marker='o', cmap = "Accent")
ax.set_title("The Plot Of The Clusters")
plt.show()

# %%
fig = sns.countplot(x=df["Clusters"], palette= "Accent")
fig.set_title("Distribution Of The Clusters")
plt.show()

# %% [markdown]
# Just clustered into three groups for wine
